# %%
import numpy as np 
import pandas as pd 
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/parkinsons-data-set/parkinsons.data
# /kaggle/input/parkinsons-data-set/parkinsons.names

# %%
data=pd.read_csv('/kaggle/input/parkinsons-data-set/parkinsons.data')
data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
def info(data):
    print(data.shape)
    print(data.size)
    
def missing(data):
    a,b = data.shape
    x = data.size
    if (a*b == x):
        print('No missing values! Go on exploring the data!')
print(info(data))
print(missing(data))
# Out:
# (195, 24)
# 4680
# None
# No missing values! Go on exploring the data!
# None

# %%
features = data.drop(columns=['status','name'])
target   = data[['status']]
print(features.head())
print(target.head())
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# ...

# %%
X=features
y=target

# %%
X_train, X_test, y_train, y_test = train_test_split(features,target,train_size=0.80, test_size=0.20)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5d1c7bd00aa5> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(indep,target,train_size=0.80, test_size=0.20)
#       2 X_train.shape, X_test.shape, y_train.shape, y_test.shape
#
# NameError: name 'indep' is not defined

# %%
tpot = TPOTClassifier(verbosity=2, max_time_mins=10)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))

# %%
tpot.fitted_pipeline_

# %%
print(tpot.score(X_test, y_test))

# %%
tpot.export('Diabetes_Prediction.py')
